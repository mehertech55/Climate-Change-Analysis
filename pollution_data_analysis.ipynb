# %% [markdown]
# <h1>Loading and analyzing data</h1>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/pollution_us_2000_2016.csv')

# %%
data.shape
# Out:
# (1746661, 29)

# %%
data.head()
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
# 4           4           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#    Date Local          NO2 Units  ...          SO2 Units  SO2 Mean  \
# 0  2000-01-01  Parts per billion  ...  Parts per billion  3.000000
# 1  2000-01-01  Parts per billion  ...  Parts per billion  3.000000
# 2  2000-01-01  Parts per billion  ...  Parts per billion  2.975000
# 3  2000-01-01  Parts per billion  ...  Parts per billion  2.975000
# 4  2000-01-02  Parts per billion  ...  Parts per billion  1.958333
#
#    SO2 1st Max Value  SO2 1st Max Hour SO2 AQI           CO Units   CO Mean  \
# 0                9.0                21    13.0  Parts per million  1.145833
# 1                9.0                21    13.0  Parts per million  0.878947
# 2                6.6                23     NaN  Parts per million  1.145833
# 3                6.6                23     NaN  Parts per million  0.878947
# 4                3.0                22     4.0  Parts per million  0.850000
#
#    CO 1st Max Value  CO 1st Max Hour CO AQI
# 0               4.2               21    NaN
# 1               2.2               23   25.0
# 2               4.2               21    NaN
# 3               2.2               23   25.0
# 4               1.6               23    NaN
#
# [5 rows x 29 columns]

# %%
data.size
# Out:
# 50653169

# %%
data.describe()
# Out:
#          Unnamed: 0    State Code   County Code      Site Num      NO2 Mean  \
# count  1.746661e+06  1.746661e+06  1.746661e+06  1.746661e+06  1.746661e+06
# mean   5.471414e+04  2.230907e+01  7.169381e+01  1.118214e+03  1.282193e+01
# std    3.372908e+04  1.725621e+01  7.948023e+01  2.003103e+03  9.504814e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00 -2.000000e+00
# 25%    2.575300e+04  6.000000e+00  1.700000e+01  9.000000e+00  5.750000e+00
# 50%    5.304500e+04  1.700000e+01  5.900000e+01  6.000000e+01  1.073913e+01
# 75%    8.033600e+04  4.000000e+01  9.700000e+01  1.039000e+03  1.771364e+01
# max    1.345750e+05  8.000000e+01  6.500000e+02  9.997000e+03  1.395417e+02
#
#        NO2 1st Max Value  NO2 1st Max Hour       NO2 AQI       O3 Mean  \
# count       1.746661e+06      1.746661e+06  1.746661e+06  1.746661e+06
# mean        2.541485e+01      1.173102e+01  2.389822e+01  2.612485e-02
# std         1.599963e+01      7.877501e+00  1.516280e+01  1.136974e-02
# min        -2.000000e+00      0.000000e+00  0.000000e+00  0.000000e+00
# 25%         1.300000e+01      5.000000e+00  1.200000e+01  1.787500e-02
# 50%         2.400000e+01      9.000000e+00  2.300000e+01  2.587500e-02
# 75%         3.570000e+01      2.000000e+01  3.300000e+01  3.391700e-02
# max         2.670000e+02      2.300000e+01  1.320000e+02  9.508300e-02
#
#        O3 1st Max Value  O3 1st Max Hour        O3 AQI      SO2 Mean  \
# count      1.746661e+06     1.746661e+06  1.746661e+06  1.746661e+06
# mean       3.920331e-02     1.017053e+01  3.605012e+01  1.870364e+00
# std        1.534362e-02     4.003144e+00  1.978042e+01  2.760435e+00
# min        0.000000e+00     0.000000e+00  0.000000e+00 -2.000000e+00
# 25%        2.900000e-02     9.000000e+00  2.500000e+01  2.565220e-01
# 50%        3.800000e-02     1.000000e+01  3.300000e+01  9.875000e-01
# 75%        4.800000e-02     1.100000e+01  4.200000e+01  2.325000e+00
# max        1.410000e-01     2.300000e+01  2.180000e+02  3.216250e+02
#
#        SO2 1st Max Value  SO2 1st Max Hour        SO2 AQI       CO Mean  \
# count       1.746661e+06      1.746661e+06  873754.000000  1.746661e+06
# mean        4.492185e+00      9.664906e+00       7.115945  3.682177e-01
# std         7.679866e+00      6.731228e+00      11.937473  3.140231e-01
# min        -2.000000e+00      0.000000e+00       0.000000 -4.375000e-01
# 25%         8.000000e-01      5.000000e+00       1.000000  1.834580e-01
# 50%         2.000000e+00      8.000000e+00       3.000000  2.926250e-01
# 75%         5.000000e+00      1.400000e+01       9.000000  4.666670e-01
# max         3.510000e+02      2.300000e+01     200.000000  7.508333e+00
#
#        CO 1st Max Value  CO 1st Max Hour         CO AQI
# count      1.746661e+06     1.746661e+06  873338.000000
# mean       6.201067e-01     7.875026e+00       5.996595
# std        6.439361e-01     7.978844e+00       5.851836
# min       -4.000000e-01     0.000000e+00       0.000000
# 25%        2.920000e-01     0.000000e+00       2.000000
# 50%        4.000000e-01     6.000000e+00       5.000000
# 75%        8.000000e-01     1.300000e+01       8.000000
# max        1.990000e+01     2.300000e+01     201.000000

# %%
data.values
# Out:
# array([[0, 4, 13, ..., 4.2, 21, nan],
#        [1, 4, 13, ..., 2.2, 23, 25.0],
#        [2, 4, 13, ..., 4.2, 21, nan],
#        ...,
#        [24601, 56, 21, ..., 0.1, 0, 1.0],
#        [24602, 56, 21, ..., 0.127, 0, nan],
#        [24603, 56, 21, ..., 0.1, 0, 1.0]], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746661 entries, 0 to 1746660
# Data columns (total 29 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   State Code         int64
#  2   County Code        int64
#  3   Site Num           int64
#  4   Address            object
#  5   State              object
#  6   County             object
#  7   City               object
#  8   Date Local         object
#  9   NO2 Units          object
#  10  NO2 Mean           float64
#  11  NO2 1st Max Value  float64
#  12  NO2 1st Max Hour   int64
#  13  NO2 AQI            int64
#  14  O3 Units           object
#  15  O3 Mean            float64
#  16  O3 1st Max Value   float64
#  17  O3 1st Max Hour    int64
#  18  O3 AQI             int64
#  19  SO2 Units          object
#  20  SO2 Mean           float64
#  21  SO2 1st Max Value  float64
#  22  SO2 1st Max Hour   int64
#  23  SO2 AQI            float64
#  24  CO Units           object
#  25  CO Mean            float64
#  26  CO 1st Max Value   float64
#  27  CO 1st Max Hour    int64
#  28  CO AQI             float64
# dtypes: float64(10), int64(10), object(9)
# memory usage: 386.5+ MB

# %% [markdown]
# <h1>Cleaning the data</h1>

# %%
data = data.drop([x for x in data.columns if x not in ['State', 'City', 'NO2 Mean', 'O3 Mean', 'SO2 Mean', 'CO Mean', 'Date Local']], axis=1)

# %%
data.head()
# Out:
#      State     City  Date Local   NO2 Mean   O3 Mean  SO2 Mean   CO Mean
# 0  Arizona  Phoenix  2000-01-01  19.041667  0.022500  3.000000  1.145833
# 1  Arizona  Phoenix  2000-01-01  19.041667  0.022500  3.000000  0.878947
# 2  Arizona  Phoenix  2000-01-01  19.041667  0.022500  2.975000  1.145833
# 3  Arizona  Phoenix  2000-01-01  19.041667  0.022500  2.975000  0.878947
# 4  Arizona  Phoenix  2000-01-02  22.958333  0.013375  1.958333  0.850000

# %%
cities_to_drop = data[~(data.City == 'Los Angeles') & 
                       ~(data.City == 'San Diego') & 
                       ~(data.City == 'San Francisco') & 
                       ~(data.City == 'New York') & 
                       ~(data.City == 'Newark') & 
                       ~(data.City == 'Philadelphia') & 
                       ~(data.City == 'Denver') a& 
                       ~(data.City == 'Dallas') & 
                       ~(data.City == 'Houston') & 
                       ~(data.City == 'Portland') & 
                       ~(data.City == 'Chicago') & 
                       ~(data.City == 'Phoenix') & 
                       ~(data.City == 'Detroit') & 
                       ~(data.City == 'Boston')
                       ].index

# %%
cities_to_drop
# Out:
# Int64Index([   1396,    1397,    1398,    1399,    1400,    1401,    1402,
#                1403,    1404,    1405,
#             ...
#             1746651, 1746652, 1746653, 1746654, 1746655, 1746656, 1746657,
#             1746658, 1746659, 1746660],
#            dtype='int64', length=1429756)

# %%
data.drop(cities_to_drop, inplace=True)

# %%
data
# Out:
#            State     City  Date Local   NO2 Mean   O3 Mean  SO2 Mean   CO Mean
# 0        Arizona  Phoenix  2000-01-01  19.041667  0.022500  3.000000  1.145833
# 1        Arizona  Phoenix  2000-01-01  19.041667  0.022500  3.000000  0.878947
# 2        Arizona  Phoenix  2000-01-01  19.041667  0.022500  2.975000  1.145833
# 3        Arizona  Phoenix  2000-01-01  19.041667  0.022500  2.975000  0.878947
# 4        Arizona  Phoenix  2000-01-02  22.958333  0.013375  1.958333  0.850000
# ...          ...      ...         ...        ...       ...       ...       ...
# 1744946    Texas  Houston  2016-03-30   9.700000  0.014250 -0.187500  0.166667
# 1744947    Texas  Houston  2016-03-31  11.066667  0.018263 -0.141667  0.214250
# 1744948    Texas  Houston  2016-03-31  11.066667  0.018263 -0.141667  0.179167
# 1744949    Texas  Houston  2016-03-31  11.066667  0.018263 -0.112500  0.214250
# 1744950    Texas  Houston  2016-03-31  11.066667  0.018263 -0.112500  0.179167
#
# [316905 rows x 7 columns]

# %%
data.columns = ["State", "City", "Date", "NO2", "O3", "SO2", "CO"]

# %%
data.head()
# Out:
#      State     City        Date        NO2        O3       SO2        CO
# 0  Arizona  Phoenix  2000-01-01  19.041667  0.022500  3.000000  1.145833
# 1  Arizona  Phoenix  2000-01-01  19.041667  0.022500  3.000000  0.878947
# 2  Arizona  Phoenix  2000-01-01  19.041667  0.022500  2.975000  1.145833
# 3  Arizona  Phoenix  2000-01-01  19.041667  0.022500  2.975000  0.878947
# 4  Arizona  Phoenix  2000-01-02  22.958333  0.013375  1.958333  0.850000

# %%
data.describe()
# Out:
#                  NO2             O3            SO2             CO
# count  316905.000000  316905.000000  316905.000000  316905.000000
# mean       19.194881       0.022196       2.460756       0.466147
# std        10.557173       0.010813       3.173368       0.349340
# min        -0.152174       0.000000      -1.728571      -0.400000
# 25%        11.208333       0.014042       0.541667       0.238333
# 50%        17.605000       0.021667       1.471429       0.374583
# 75%        25.565217       0.029625       3.162500       0.591667
# max        98.130435       0.079458      53.500000       4.246667

# %%
data['Year'] = pd.DatetimeIndex(data['Date']).year

# %%
data['Month'] = pd.DatetimeIndex(data['Date']).month

# %%
data['Day'] = pd.DatetimeIndex(data['Date']).day

# %%
data
# Out:
#            State     City        Date        NO2        O3       SO2  \
# 0        Arizona  Phoenix  2000-01-01  19.041667  0.022500  3.000000
# 1        Arizona  Phoenix  2000-01-01  19.041667  0.022500  3.000000
# 2        Arizona  Phoenix  2000-01-01  19.041667  0.022500  2.975000
# 3        Arizona  Phoenix  2000-01-01  19.041667  0.022500  2.975000
# 4        Arizona  Phoenix  2000-01-02  22.958333  0.013375  1.958333
# ...          ...      ...         ...        ...       ...       ...
# 1744946    Texas  Houston  2016-03-30   9.700000  0.014250 -0.187500
# 1744947    Texas  Houston  2016-03-31  11.066667  0.018263 -0.141667
# 1744948    Texas  Houston  2016-03-31  11.066667  0.018263 -0.141667
# 1744949    Texas  Houston  2016-03-31  11.066667  0.018263 -0.112500
# 1744950    Texas  Houston  2016-03-31  11.066667  0.018263 -0.112500
#
#                CO  Year  Month  Day
# 0        1.145833  2000      1    1
# 1        0.878947  2000      1    1
# 2        1.145833  2000      1    1
# 3        0.878947  2000      1    1
# 4        0.850000  2000      1    2
# ...           ...   ...    ...  ...
# 1744946  0.166667  2016      3   30
# 1744947  0.214250  2016      3   31
# 1744948  0.179167  2016      3   31
# 1744949  0.214250  2016      3   31
# 1744950  0.179167  2016      3   31
#
# [316905 rows x 10 columns]

# %% [markdown]
# <h3><i>Testing with Phoenix data</i></h3>

# %%
phoenix = data['City'] == 'Phoenix'
phoenix = data[phoenix]

# %%
phoenix
# Out:
#            State     City        Date        NO2        O3       SO2  \
# 0        Arizona  Phoenix  2000-01-01  19.041667  0.022500  3.000000
# 1        Arizona  Phoenix  2000-01-01  19.041667  0.022500  3.000000
# 2        Arizona  Phoenix  2000-01-01  19.041667  0.022500  2.975000
# 3        Arizona  Phoenix  2000-01-01  19.041667  0.022500  2.975000
# 4        Arizona  Phoenix  2000-01-02  22.958333  0.013375  1.958333
# ...          ...      ...         ...        ...       ...       ...
# 1722964  Arizona  Phoenix  2016-03-25  17.308333  0.027125  0.425000
# 1722965  Arizona  Phoenix  2016-03-26  14.579167  0.042053  0.637500
# 1722966  Arizona  Phoenix  2016-03-26  14.579167  0.042053  0.637500
# 1722967  Arizona  Phoenix  2016-03-26  14.579167  0.042053  0.600000
# 1722968  Arizona  Phoenix  2016-03-26  14.579167  0.042053  0.600000
#
#                CO  Year  Month  Day
# 0        1.145833  2000      1    1
# 1        0.878947  2000      1    1
# 2        1.145833  2000      1    1
# 3        0.878947  2000      1    1
# 4        0.850000  2000      1    2
# ...           ...   ...    ...  ...
# 1722964  0.470833  2016      3   25
# 1722965  0.433000  2016      3   26
# 1722966  0.454167  2016      3   26
# 1722967  0.433000  2016      3   26
# 1722968  0.454167  2016      3   26
#
# [37912 rows x 10 columns]

# %%
def get_avg_per_month_year(data, year_range=(2000, 2017), month_range=(1, 13)):
    avg_year_month = {'NO2': {}, 'O3': {}, 'SO2': {}, 'CO': {}}
    
    for year in range(year_range[0], year_range[1]):
        for month in range(month_range[0], month_range[1]):
            data_mean = (data['Year'] == year) & (data['Month'] == month)
            data_mean_values = data[data_mean][['NO2', 'O3', 'SO2', 'CO']].mean()
            year_month = str(year) + '-' + ('0'+str(month) if len(str(month))== 1 else str(month))
            
            avg_year_month['NO2'][year_month] = round(data_mean_values['NO2'], 4)
            avg_year_month['O3'][year_month] = round(data_mean_values['O3'], 4)
            avg_year_month['SO2'][year_month] = round(data_mean_values['SO2'], 4)
            avg_year_month['CO'][year_month] = round(data_mean_values['CO'], 4)
    return avg_year_month

# %%
phoenix_avg_gases = get_avg_per_month_year(data=phoenix)
phoenix_avg_gases
# Out:
# {'NO2': {'2000-01': 43.2035,
#   '2000-02': 36.4951,
#   '2000-03': 32.9162,
#   '2000-04': 28.9058,
#   '2000-05': 2.8722,
#   '2000-06': 26.0772,
#   '2000-07': 23.2365,
#   '2000-08': 21.9917,
#   '2000-09': 29.3008,
#   '2000-10': 29.6933,
#   '2000-11': 33.8007,
#   '2000-12': 38.4623,
#   '2001-01': 32.6003,
#   '2001-02': 31.1294,
#   '2001-03': 31.3342,
#   '2001-04': 26.9202,
#   '2001-05': 26.9074,
#   '2001-06': 22.9778,
#   '2001-07': 18.7449,
#   '2001-08': 24.6276,
#   '2001-09': 25.9321,
#   '2001-10': 32.7431,
#   '2001-11': 33.7111,
#   '2001-12': 38.1529,
#   '2002-01': 38.9007,
#   '2002-02': 38.0782,
#   '2002-03': 29.1325,
#   '2002-04': 24.3743,
#   '2002-05': 26.6403,
#   '2002-06': 26.4893,
#   '2002-07': 19.7942,
#   '2002-08': 21.5516,
#   '2002-09': 25.7628,
#   '2002-10': 34.7219,
#   '2002-11': 36.1358,
#   '2002-12': 34.0158,
#   '2003-01': 38.6143,
#   '2003-02': 32.3204,
#   '2003-03': 31.0784,
#   '2003-04': 26.045,
#   '2003-05': 26.1877,
#   '2003-06': 20.3053,
#   '2003-07': 17.2379,
#   '2003-08': nan,
#   '2003-09': nan,
#   '2003-10': 33.0882,
#   '2003-11': 32.5687,
#   '2003-12': 36.2333,
#   '2004-01': 33.3806,
#   '2004-02': 31.7858,
#   '2004-03': 28.987,
#   '2004-04': 23.669,
#   '2004-05': 19.8669,
#   '2004-06': 20.3001,
#   '2004-07': 17.491,
#   '2004-08': 19.5506,
#   '2004-09': 24.1713,
#   '2004-10': 24.3899,
#   '2004-11': 24.7747,
#   '2004-12': 31.5866,
#   '2005-01': 29.0541,
#   '2005-02': 25.367,
#   '2005-03': 22.9989,
#   '2005-04': 24.3042,
#   '2005-05': 21.7496,
#   '2005-06': 20.0375,
#   '2005-07': 17.3537,
#   '2005-08': 17.3214,
#   '2005-09': 24.0215,
#   '2005-10': 26.2297,
#   '2005-11': 32.5083,
#   '2005-12': 38.2782,
#   '2006-01': 33.7471,
#   '2006-02': 34.4239,
#   '2006-03': 23.7879,
#   '2006-04': 22.7992,
#   '2006-05': 19.7661,
#   '2006-06': 17.4034,
#   '2006-07': 10.5312,
#   '2006-08': 13.7399,
#   '2006-09': 18.2564,
#   '2006-10': 23.8808,
#   '2006-11': 34.3547,
#   '2006-12': 31.5027,
#   '2007-01': 29.081,
#   '2007-02': 26.1995,
#   '2007-03': 26.1122,
#   '2007-04': 20.1138,
#   '2007-05': 19.6162,
#   '2007-06': 19.2726,
#   '2007-07': 12.1707,
#   '2007-08': 13.452,
#   '2007-09': 18.0277,
#   '2007-10': 24.5637,
#   '2007-11': 31.9869,
#   '2007-12': 27.2161,
#   '2008-01': 25.1848,
#   '2008-02': 26.5422,
#   '2008-03': 24.9591,
#   '2008-04': 21.1039,
#   '2008-05': 16.6332,
#   '2008-06': 18.0243,
#   '2008-07': 11.1704,
#   '2008-08': 11.7454,
#   '2008-09': 17.8723,
#   '2008-10': 24.9603,
#   '2008-11': 25.4417,
#   '2008-12': 24.2124,
#   '2009-01': 25.1177,
#   '2009-02': 23.8362,
#   '2009-03': 21.4766,
#   '2009-04': 18.1922,
#   '2009-05': 15.2835,
#   '2009-06': 13.3127,
#   '2009-07': 9.7213,
#   '2009-08': 14.6909,
#   '2009-09': 16.3276,
#   '2009-10': 21.389,
#   '2009-11': 27.8221,
#   '2009-12': 27.0107,
#   '2010-01': 25.1949,
#   '2010-02': 21.9043,
#   '2010-03': 18.5338,
#   '2010-04': 14.6548,
#   '2010-05': 15.0609,
#   '2010-06': 13.3669,
#   '2010-07': 6.7136,
#   '2010-08': 11.6034,
#   '2010-09': 20.0731,
#   '2010-10': 18.3762,
#   '2010-11': 23.0479,
#   '2010-12': 26.1213,
#   '2011-01': 28.5845,
#   '2011-02': 22.0736,
#   '2011-03': 22.1734,
#   '2011-04': 11.9923,
#   '2011-05': 12.3719,
#   '2011-06': 16.3706,
#   '2011-07': 9.7433,
#   '2011-08': 13.7174,
#   '2011-09': 18.7472,
#   '2011-10': 25.1612,
#   '2011-11': 22.8715,
#   '2011-12': 23.4258,
#   '2012-01': 26.5323,
#   '2012-02': 23.4607,
#   '2012-03': 20.9207,
#   '2012-04': 18.4257,
#   '2012-05': 16.3457,
#   '2012-06': 12.9644,
#   '2012-07': 9.8357,
#   '2012-08': 13.3275,
#   '2012-09': 16.0865,
#   '2012-10': 24.4121,
#   '2012-11': 29.3861,
#   '2012-12': 25.8311,
#   '2013-01': 27.0628,
#   '2013-02': 24.5527,
#   '2013-03': 23.489,
#   '2013-04': 14.4204,
#   '2013-05': 13.1127,
#   '2013-06': 14.2534,
#   '2013-07': 8.4581,
#   '2013-08': 12.2678,
#   '2013-09': 16.1501,
#   '2013-10': 21.4781,
#   '2013-11': 20.7866,
#   '2013-12': 24.3259,
#   '2014-01': 28.6716,
#   '2014-02': 25.2699,
#   '2014-03': 18.4993,
#   '2014-04': 15.5631,
#   '2014-05': 12.3681,
#   '2014-06': 14.1138,
#   '2014-07': 8.5212,
#   '2014-08': 10.9285,
#   '2014-09': 13.5385,
#   '2014-10': 22.128,
#   '2014-11': 22.7954,
#   '2014-12': 22.6824,
#   '2015-01': 22.4797,
#   '2015-02': 21.1667,
#   '2015-03': 19.0567,
#   '2015-04': 14.3007,
#   '2015-05': 11.118,
#   '2015-06': 10.8264,
#   '2015-07': 7.4533,
#   '2015-08': 9.6219,
#   '2015-09': 12.1304,
#   '2015-10': 10.0799,
#   '2015-11': 23.3759,
#   '2015-12': 26.9501,
#   '2016-01': 21.1448,
#   '2016-02': 22.7075,
#   '2016-03': 17.148,
#   '2016-04': nan,
#   '2016-05': nan,
#   '2016-06': nan,
#   '2016-07': nan,
#   '2016-08': nan,
#   '2016-09': nan,
#   '2016-10': nan,
#   '2016-11': nan,
#   '2016-12': nan},
#  'O3': {'2000-01': 0.0112,
#   '2000-02': 0.0165,
#   '2000-03': 0.023,
#   '2000-04': 0.0284,
#   '2000-05': 0.0315,
#   '2000-06': 0.028,
#   '2000-07': 0.0311,
#   '2000-08': 0.0383,
#   '2000-09': 0.0199,
#   '2000-10': 0.0164,
#   '2000-11': 0.0087,
#   '2000-12': 0.0073,
#   '2001-01': 0.0107,
#   '2001-02': 0.012,
#   '2001-03': 0.018,
#   '2001-04': 0.0268,
#   '2001-05': 0.0274,
#   '2001-06': 0.0287,
#   '2001-07': 0.03,
#   '2001-08': 0.0318,
#   '2001-09': 0.0209,
#   '2001-10': 0.0158,
#   '2001-11': 0.0112,
#   '2001-12': 0.0073,
#   '2002-01': 0.009,
#   '2002-02': 0.0152,
#   '2002-03': 0.0238,
#   '2002-04': 0.0251,
#   '2002-05': 0.0301,
#   '2002-06': 0.0291,
#   '2002-07': 0.0294,
#   '2002-08': 0.0276,
#   '2002-09': 0.023,
#   '2002-10': 0.0166,
#   '2002-11': 0.014,
#   '2002-12': 0.0076,
#   '2003-01': 0.0072,
#   '2003-02': 0.0122,
#   '2003-03': 0.0195,
#   '2003-04': 0.0288,
#   '2003-05': 0.0334,
#   '2003-06': 0.0299,
#   '2003-07': 0.0374,
#   '2003-08': nan,
#   '2003-09': nan,
#   '2003-10': 0.0157,
#   '2003-11': 0.0116,
#   '2003-12': 0.0098,
#   '2004-01': 0.0108,
#   '2004-02': 0.015,
#   '2004-03': 0.0199,
#   '2004-04': 0.0321,
#   '2004-05': 0.0303,
#   '2004-06': 0.0269,
#   '2004-07': 0.0305,
#   '2004-08': 0.0273,
#   '2004-09': 0.0245,
#   '2004-10': 0.0192,
#   '2004-11': 0.0125,
#   '2004-12': 0.0098,
#   '2005-01': 0.0092,
#   '2005-02': 0.0148,
#   '2005-03': 0.0239,
#   '2005-04': 0.0303,
#   '2005-05': 0.0294,
#   '2005-06': 0.0331,
#   '2005-07': 0.0334,
#   '2005-08': 0.0302,
#   '2005-09': 0.0243,
#   '2005-10': 0.018,
#   '2005-11': 0.0114,
#   '2005-12': 0.006,
#   '2006-01': 0.012,
#   '2006-02': 0.0144,
#   '2006-03': 0.0237,
#   '2006-04': 0.0296,
#   '2006-05': 0.0323,
#   '2006-06': 0.038,
#   '2006-07': 0.0396,
#   '2006-08': 0.0327,
#   '2006-09': 0.0261,
#   '2006-10': 0.0182,
#   '2006-11': 0.0133,
#   '2006-12': 0.0102,
#   '2007-01': 0.0121,
#   '2007-02': 0.0157,
#   '2007-03': 0.0224,
#   '2007-04': 0.0329,
#   '2007-05': 0.0344,
#   '2007-06': 0.0311,
#   '2007-07': 0.0359,
#   '2007-08': 0.0341,
#   '2007-09': 0.0272,
#   '2007-10': 0.0197,
#   '2007-11': 0.0117,
#   '2007-12': 0.0102,
#   '2008-01': 0.0141,
#   '2008-02': 0.0143,
#   '2008-03': 0.0244,
#   '2008-04': 0.0358,
#   '2008-05': 0.0389,
#   '2008-06': 0.0362,
#   '2008-07': 0.0364,
#   '2008-08': 0.0361,
#   '2008-09': 0.0288,
#   '2008-10': 0.0203,
#   '2008-11': 0.014,
#   '2008-12': 0.0103,
#   '2009-01': 0.011,
#   '2009-02': 0.0174,
#   '2009-03': 0.027,
#   '2009-04': 0.0351,
#   '2009-05': 0.0345,
#   '2009-06': 0.0302,
#   '2009-07': 0.038,
#   '2009-08': 0.0315,
#   '2009-09': 0.0299,
#   '2009-10': 0.022,
#   '2009-11': 0.0129,
#   '2009-12': 0.0111,
#   '2010-01': 0.0149,
#   '2010-02': 0.0187,
#   '2010-03': 0.0271,
#   '2010-04': 0.0353,
#   '2010-05': 0.0378,
#   '2010-06': 0.0365,
#   '2010-07': 0.0386,
#   '2010-08': 0.0329,
#   '2010-09': 0.0267,
#   '2010-10': 0.0227,
#   '2010-11': 0.0167,
#   '2010-12': 0.0096,
#   '2011-01': 0.0118,
#   '2011-02': 0.0205,
#   '2011-03': 0.0257,
#   '2011-04': 0.0389,
#   '2011-05': 0.0391,
#   '2011-06': 0.0357,
#   '2011-07': 0.0373,
#   '2011-08': 0.037,
#   '2011-09': 0.0299,
#   '2011-10': 0.0196,
#   '2011-11': 0.0159,
#   '2011-12': 0.0141,
#   '2012-01': 0.0119,
#   '2012-02': 0.0206,
#   '2012-03': 0.0267,
#   '2012-04': 0.0337,
#   '2012-05': 0.0393,
#   '2012-06': 0.0343,
#   '2012-07': 0.0382,
#   '2012-08': 0.0392,
#   '2012-09': 0.0302,
#   '2012-10': 0.0212,
#   '2012-11': 0.0136,
#   '2012-12': 0.014,
#   '2013-01': 0.0131,
#   '2013-02': 0.0191,
#   '2013-03': 0.0236,
#   '2013-04': 0.0327,
#   '2013-05': 0.0432,
#   '2013-06': 0.0315,
#   '2013-07': 0.0408,
#   '2013-08': 0.0362,
#   '2013-09': 0.0308,
#   '2013-10': 0.0227,
#   '2013-11': 0.0184,
#   '2013-12': 0.0141,
#   '2014-01': 0.0126,
#   '2014-02': 0.017,
#   '2014-03': 0.0287,
#   '2014-04': 0.0365,
#   '2014-05': 0.0413,
#   '2014-06': 0.0325,
#   '2014-07': 0.0393,
#   '2014-08': 0.0354,
#   '2014-09': 0.0284,
#   '2014-10': 0.0225,
#   '2014-11': 0.0166,
#   '2014-12': 0.0118,
#   '2015-01': 0.0129,
#   '2015-02': 0.0199,
#   '2015-03': 0.0268,
#   '2015-04': 0.0367,
#   '2015-05': 0.0394,
#   '2015-06': 0.039,
#   '2015-07': 0.0339,
#   '2015-08': 0.0366,
#   '2015-09': 0.0277,
#   '2015-10': 0.0218,
#   '2015-11': 0.0163,
#   '2015-12': 0.0111,
#   '2016-01': 0.0139,
#   '2016-02': 0.018,
#   '2016-03': 0.0278,
#   '2016-04': nan,
#   '2016-05': nan,
#   '2016-06': nan,
#   '2016-07': nan,
#   '2016-08': nan,
#   '2016-09': nan,
#   '2016-10': nan,
#   '2016-11': nan,
#   '2016-12': nan},
#  'SO2': {'2000-01': 7.4368,
#   '2000-02': 3.8742,
#   '2000-03': 0.5606,
#   '2000-04': 1.5487,
#   '2000-05': 1.5855,
#   '2000-06': 0.9881,
#   '2000-07': 0.8846,
#   '2000-08': 1.0367,
#   '2000-09': 1.8203,
#   '2000-10': 1.6344,
#   '2000-11': 2.0473,
#   '2000-12': 4.2633,
#   '2001-01': 2.256,
#   '2001-02': 2.0167,
#   '2001-03': 1.999,
#   '2001-04': 0.9028,
#   '2001-05': 1.9811,
#   '2001-06': 1.4252,
#   '2001-07': 1.5871,
#   '2001-08': 1.1245,
#   '2001-09': 4.0695,
#   '2001-10': 4.9105,
#   '2001-11': 2.4692,
#   '2001-12': 4.852,
#   '2002-01': 4.6881,
#   '2002-02': 3.8782,
#   '2002-03': 2.8286,
#   '2002-04': 2.4004,
#   '2002-05': 3.7134,
#   '2002-06': 2.221,
#   '2002-07': 1.1781,
#   '2002-08': 1.8877,
#   '2002-09': 1.3778,
#   '2002-10': 2.1407,
#   '2002-11': 3.1655,
#   '2002-12': 2.5353,
#   '2003-01': 4.5092,
#   '2003-02': 2.8816,
#   '2003-03': 1.4583,
#   '2003-04': 2.0243,
#   '2003-05': 1.8053,
#   '2003-06': 3.3815,
#   '2003-07': 1.8416,
#   '2003-08': nan,
#   '2003-09': nan,
#   '2003-10': 1.9331,
#   '2003-11': 2.8537,
#   '2003-12': 3.0854,
#   '2004-01': 3.1399,
#   '2004-02': 2.4462,
#   '2004-03': 1.7534,
#   '2004-04': 0.9166,
#   '2004-05': 0.6867,
#   '2004-06': 1.1082,
#   '2004-07': 2.0637,
#   '2004-08': 2.7019,
#   '2004-09': 3.3725,
#   '2004-10': 3.0347,
#   '2004-11': 2.3236,
#   '2004-12': 4.475,
#   '2005-01': 1.4109,
#   '2005-02': 0.8192,
#   '2005-03': 1.9692,
#   '2005-04': 2.3095,
#   '2005-05': 2.8622,
#   '2005-06': 3.0462,
#   '2005-07': 2.1206,
#   '2005-08': 1.5388,
#   '2005-09': 1.8843,
#   '2005-10': 2.3367,
#   '2005-11': 3.9169,
#   '2005-12': 3.4618,
#   '2006-01': 3.1319,
#   '2006-02': 2.9141,
#   '2006-03': 1.4916,
#   '2006-04': 2.0569,
#   '2006-05': 1.3392,
#   '2006-06': 1.6925,
#   '2006-07': 1.4075,
#   '2006-08': 1.973,
#   '2006-09': 2.4048,
#   '2006-10': 1.8587,
#   '2006-11': 2.0737,
#   '2006-12': 2.4063,
#   '2007-01': 2.5011,
#   '2007-02': 2.6259,
#   '2007-03': 2.2358,
#   '2007-04': 1.8288,
#   '2007-05': 1.5997,
#   '2007-06': 1.8624,
#   '2007-07': 1.6958,
#   '2007-08': 1.2641,
#   '2007-09': 1.1677,
#   '2007-10': 1.5101,
#   '2007-11': 1.9527,
#   '2007-12': 1.6062,
#   '2008-01': 1.6515,
#   '2008-02': 1.9205,
#   '2008-03': 1.885,
#   '2008-04': 2.1536,
#   '2008-05': 1.646,
#   '2008-06': 1.2988,
#   '2008-07': 1.5447,
#   '2008-08': 1.1444,
#   '2008-09': 2.1804,
#   '2008-10': 2.4855,
#   '2008-11': 2.4439,
#   '2008-12': 2.4085,
#   '2009-01': 2.4656,
#   '2009-02': 1.8947,
#   '2009-03': 1.8583,
#   '2009-04': 1.6294,
#   '2009-05': 0.9501,
#   '2009-06': 0.8059,
#   '2009-07': 0.4791,
#   '2009-08': 1.8222,
#   '2009-09': 2.1095,
#   '2009-10': 0.983,
#   '2009-11': 2.1257,
#   '2009-12': 2.1948,
#   '2010-01': 2.0763,
#   '2010-02': 1.2374,
#   '2010-03': 1.2169,
#   '2010-04': 1.1584,
#   '2010-05': 1.225,
#   '2010-06': 1.0951,
#   '2010-07': 0.9089,
#   '2010-08': 1.1923,
#   '2010-09': 2.0629,
#   '2010-10': 1.0023,
#   '2010-11': 1.5111,
#   '2010-12': 1.943,
#   '2011-01': 1.5165,
#   '2011-02': 0.9068,
#   '2011-03': 1.1745,
#   '2011-04': 1.0493,
#   '2011-05': 0.9984,
#   '2011-06': 0.9269,
#   '2011-07': 0.5069,
#   '2011-08': 0.8548,
#   '2011-09': 0.8627,
#   '2011-10': 1.397,
#   '2011-11': 1.2169,
#   '2011-12': 1.4063,
#   '2012-01': 1.7883,
#   '2012-02': 1.15,
#   '2012-03': 0.8069,
#   '2012-04': 0.8203,
#   '2012-05': 0.9806,
#   '2012-06': 1.0497,
#   '2012-07': 1.0782,
#   '2012-08': 1.0671,
#   '2012-09': 1.268,
#   '2012-10': 1.5224,
#   '2012-11': 1.9124,
#   '2012-12': 1.5254,
#   '2013-01': 1.6716,
#   '2013-02': 1.2292,
#   '2013-03': 1.1169,
#   '2013-04': 0.9766,
#   '2013-05': 0.9698,
#   '2013-06': 0.692,
#   '2013-07': 0.6178,
#   '2013-08': 0.9366,
#   '2013-09': 1.0967,
#   '2013-10': 0.9253,
#   '2013-11': 0.844,
#   '2013-12': 1.3009,
#   '2014-01': 1.7447,
#   '2014-02': 1.0454,
#   '2014-03': 0.8133,
#   '2014-04': 0.8566,
#   '2014-05': 0.9461,
#   '2014-06': 1.1235,
#   '2014-07': 1.3605,
#   '2014-08': 1.6228,
#   '2014-09': 1.2041,
#   '2014-10': 1.2592,
#   '2014-11': 1.1321,
#   '2014-12': 1.2831,
#   '2015-01': 1.232,
#   '2015-02': 0.9308,
#   '2015-03': 0.5705,
#   '2015-04': 0.462,
#   '2015-05': 0.5315,
#   '2015-06': 0.4145,
#   '2015-07': 0.7064,
#   '2015-08': 0.9594,
#   '2015-09': 1.1116,
#   '2015-10': 0.868,
#   '2015-11': 0.8735,
#   '2015-12': 1.6784,
#   '2016-01': 0.9467,
#   '2016-02': 0.7228,
#   '2016-03': 0.4204,
#   '2016-04': nan,
#   '2016-05': nan,
#   '2016-06': nan,
#   '2016-07': nan,
#   '2016-08': nan,
#   '2016-09': nan,
#   '2016-10': nan,
#   '2016-11': nan,
#   '2016-12': nan},
#  'CO': {'2000-01': 1.9932,
#   '2000-02': 1.2683,
#   '2000-03': 0.9185,
#   '2000-04': 0.9683,
#   '2000-05': 0.7759,
#   '2000-06': 0.4921,
#   '2000-07': 0.5443,
#   '2000-08': 0.4149,
#   '2000-09': 0.7533,
#   '2000-10': 0.9212,
#   '2000-11': 1.2346,
#   '2000-12': 1.7834,
#   '2001-01': 1.1578,
#   '2001-02': 1.0007,
#   '2001-03': 0.8114,
#   '2001-04': 0.7159,
#   '2001-05': 0.7287,
#   '2001-06': 0.5147,
#   '2001-07': 0.393,
#   '2001-08': 0.5816,
#   '2001-09': 0.7819,
#   '2001-10': 1.0016,
#   '2001-11': 1.1012,
#   '2001-12': 1.4845,
#   '2002-01': 1.5851,
#   '2002-02': 1.4871,
#   '2002-03': 0.9534,
#   '2002-04': 0.714,
#   '2002-05': 0.8636,
#   '2002-06': 0.6755,
#   '2002-07': 0.5073,
#   '2002-08': 0.5473,
#   '2002-09': 0.6939,
#   '2002-10': 1.2307,
#   '2002-11': 1.3506,
#   '2002-12': 1.2985,
#   '2003-01': 1.5944,
#   '2003-02': 0.8397,
#   '2003-03': 0.727,
#   '2003-04': 0.3802,
#   '2003-05': 0.4245,
#   '2003-06': 0.409,
#   '2003-07': 0.4076,
#   '2003-08': nan,
#   '2003-09': nan,
#   '2003-10': 0.9139,
#   '2003-11': 0.9732,
#   '2003-12': 1.1796,
#   '2004-01': 1.01,
#   '2004-02': 0.6715,
#   '2004-03': 0.5724,
#   '2004-04': 0.4581,
#   '2004-05': 0.3497,
#   '2004-06': 0.3269,
#   '2004-07': 0.197,
#   '2004-08': 0.2624,
#   '2004-09': 0.661,
#   '2004-10': 0.716,
#   '2004-11': 0.726,
#   '2004-12': 1.0818,
#   '2005-01': 0.8418,
#   '2005-02': 0.5594,
#   '2005-03': 0.6705,
#   '2005-04': 0.6986,
#   '2005-05': 0.6553,
#   '2005-06': 0.4764,
#   '2005-07': 0.4694,
#   '2005-08': 0.3944,
#   '2005-09': 0.5738,
#   '2005-10': 0.7784,
#   '2005-11': 1.2497,
#   '2005-12': 1.6405,
#   '2006-01': 1.1377,
#   '2006-02': 1.0208,
#   '2006-03': 0.6145,
#   '2006-04': 0.544,
#   '2006-05': 0.4023,
#   '2006-06': 0.4165,
#   '2006-07': 0.3709,
#   '2006-08': 0.3892,
#   '2006-09': 0.4972,
#   '2006-10': 0.6985,
#   '2006-11': 1.1385,
#   '2006-12': 1.0989,
#   '2007-01': 0.986,
#   '2007-02': 0.7993,
#   '2007-03': 0.5947,
#   '2007-04': 0.4493,
#   '2007-05': 0.4529,
#   '2007-06': 0.391,
#   '2007-07': 0.2629,
#   '2007-08': 0.3187,
#   '2007-09': 0.5,
#   '2007-10': 0.6814,
#   '2007-11': 0.9889,
#   '2007-12': 0.9498,
#   '2008-01': 0.7713,
#   '2008-02': 0.7201,
#   '2008-03': 0.4641,
#   '2008-04': 0.5027,
#   '2008-05': 0.5441,
#   '2008-06': 0.306,
#   '2008-07': 0.2678,
#   '2008-08': 0.189,
#   '2008-09': 0.3726,
#   '2008-10': 0.5383,
#   '2008-11': 0.7505,
#   '2008-12': 0.7581,
#   '2009-01': 0.7531,
#   '2009-02': 0.6332,
#   '2009-03': 0.4684,
#   '2009-04': 0.4614,
#   '2009-05': 0.4287,
#   '2009-06': 0.368,
#   '2009-07': 0.364,
#   '2009-08': 0.4332,
#   '2009-09': 0.322,
#   '2009-10': 0.4152,
#   '2009-11': 0.7491,
#   '2009-12': 0.7594,
#   '2010-01': 0.6521,
#   '2010-02': 0.4179,
#   '2010-03': 0.3444,
#   '2010-04': 0.3635,
#   '2010-05': 0.3401,
#   '2010-06': 0.2593,
#   '2010-07': 0.2082,
#   '2010-08': 0.2456,
#   '2010-09': 0.4148,
#   '2010-10': 0.417,
#   '2010-11': 0.6213,
#   '2010-12': 0.7628,
#   '2011-01': 0.8408,
#   '2011-02': 0.5667,
#   '2011-03': 0.4275,
#   '2011-04': 0.2416,
#   '2011-05': 0.2397,
#   '2011-06': 0.2765,
#   '2011-07': 0.203,
#   '2011-08': 0.2131,
#   '2011-09': 0.2623,
#   '2011-10': 0.4897,
#   '2011-11': 0.5078,
#   '2011-12': 0.6615,
#   '2012-01': 0.726,
#   '2012-02': 0.5538,
#   '2012-03': 0.4535,
#   '2012-04': 0.3914,
#   '2012-05': 0.2823,
#   '2012-06': 0.2069,
#   '2012-07': 0.2262,
#   '2012-08': 0.1809,
#   '2012-09': 0.2407,
#   '2012-10': 0.3735,
#   '2012-11': 0.6914,
#   '2012-12': 0.5151,
#   '2013-01': 0.551,
#   '2013-02': 0.453,
#   '2013-03': 0.4021,
#   '2013-04': 0.356,
#   '2013-05': 0.2844,
#   '2013-06': 0.2511,
#   '2013-07': 0.2893,
#   '2013-08': 0.2647,
#   '2013-09': 0.2971,
#   '2013-10': 0.4383,
#   '2013-11': 0.54,
#   '2013-12': 0.7046,
#   '2014-01': 0.8069,
#   '2014-02': 0.6019,
#   '2014-03': 0.4016,
#   '2014-04': 0.3138,
#   '2014-05': 0.3129,
#   '2014-06': 0.3171,
#   '2014-07': 0.288,
#   '2014-08': 0.3219,
#   '2014-09': 0.4241,
#   '2014-10': 0.5877,
#   '2014-11': 0.6228,
#   '2014-12': 0.7392,
#   '2015-01': 0.6989,
#   '2015-02': 0.5885,
#   '2015-03': 0.508,
#   '2015-04': 0.3669,
#   '2015-05': 0.3116,
#   '2015-06': 0.2925,
#   '2015-07': 0.1983,
#   '2015-08': 0.2934,
#   '2015-09': 0.3319,
#   '2015-10': 0.401,
#   '2015-11': 0.5673,
#   '2015-12': 0.7471,
#   '2016-01': 0.7123,
#   '2016-02': 0.7045,
#   '2016-03': 0.5051,
#   '2016-04': nan,
#   '2016-05': nan,
#   '2016-06': nan,
#   '2016-07': nan,
#   '2016-08': nan,
#   '2016-09': nan,
#   '2016-10': nan,
#   '2016-11': nan,
#   '2016-12': nan}}

# %%
phoenix_gases_df = pd.DataFrame(phoenix_avg_gases).dropna()
phoenix_gases_df = phoenix_gases_df.reset_index()
phoenix_gases_df = phoenix_gases_df.rename({'index': 'Years_Months'}, axis='columns')
phoenix_gases_df
# Out:
#     Years_Months      NO2      O3     SO2      CO
# 0        2000-01  43.2035  0.0112  7.4368  1.9932
# 1        2000-02  36.4951  0.0165  3.8742  1.2683
# 2        2000-03  32.9162  0.0230  0.5606  0.9185
# 3        2000-04  28.9058  0.0284  1.5487  0.9683
# 4        2000-05   2.8722  0.0315  1.5855  0.7759
# ..           ...      ...     ...     ...     ...
# 188      2015-11  23.3759  0.0163  0.8735  0.5673
# 189      2015-12  26.9501  0.0111  1.6784  0.7471
# 190      2016-01  21.1448  0.0139  0.9467  0.7123
# 191      2016-02  22.7075  0.0180  0.7228  0.7045
# 192      2016-03  17.1480  0.0278  0.4204  0.5051
#
# [193 rows x 5 columns]

# %% [markdown]
# <h2>Rates drop in the final of each year</h2>

# %%
phoenix_gases_df.iloc[0:24].plot.scatter(figsize=(17,10), y='O3', x='Years_Months')

# %% [markdown]
# <h3><i>Testing with New York data</i></h3>

# %%
ny = data['City'] == 'New York'
ny = data[ny]
ny
# Out:
#             State      City        Date        NO2        O3       SO2  \
# 63332    New York  New York  2000-05-05  42.500000  0.018417  8.800000
# 63333    New York  New York  2000-05-05  42.500000  0.018417  8.800000
# 63334    New York  New York  2000-05-05  42.500000  0.018417  9.600000
# 63335    New York  New York  2000-05-05  42.500000  0.018417  9.600000
# 63336    New York  New York  2000-05-06  42.875000  0.034333  9.500000
# ...           ...       ...         ...        ...       ...       ...
# 1738526  New York  New York  2016-04-29   9.041667  0.036750  0.125000
# 1738527  New York  New York  2016-04-30   8.204167  0.038684  0.245833
# 1738528  New York  New York  2016-04-30   8.204167  0.038684  0.245833
# 1738529  New York  New York  2016-04-30   8.204167  0.038684  0.212500
# 1738530  New York  New York  2016-04-30   8.204167  0.038684  0.212500
#
#                CO  Year  Month  Day
# 63332    0.866667  2000      5    5
# 63333    0.787500  2000      5    5
# 63334    0.866667  2000      5    5
# 63335    0.787500  2000      5    5
# 63336    1.187500  2000      5    6
# ...           ...   ...    ...  ...
# 1738526  0.187500  2016      4   29
# 1738527  0.170667  2016      4   30
# 1738528  0.195833  2016      4   30
# 1738529  0.170667  2016      4   30
# 1738530  0.195833  2016      4   30
#
# [46887 rows x 10 columns]

# %%
ny_avg_gases = get_avg_per_month_year(data=ny)
ny_avg_gases
# Out:
# {'NO2': {'2000-01': 26.1259,
#   '2000-02': 31.1326,
#   '2000-03': 27.975,
#   '2000-04': 22.4492,
#   '2000-05': 26.8353,
#   '2000-06': 27.0305,
#   '2000-07': 24.5067,
#   '2000-08': 25.2599,
#   '2000-09': 24.6788,
#   '2000-10': 31.0972,
#   '2000-11': 25.1448,
#   '2000-12': 28.2735,
#   '2001-01': 35.4975,
#   '2001-02': 29.3609,
#   '2001-03': 27.1735,
#   '2001-04': 29.8236,
#   '2001-05': 28.1412,
#   '2001-06': 26.4568,
#   '2001-07': 24.5561,
#   '2001-08': 28.5627,
#   '2001-09': 22.1402,
#   '2001-10': 29.3713,
#   '2001-11': 30.4998,
#   '2001-12': 28.4504,
#   '2002-01': 32.6525,
#   '2002-02': 31.1545,
#   '2002-03': 29.0502,
#   '2002-04': 29.2794,
#   '2002-05': 24.6186,
#   '2002-06': 27.7887,
#   '2002-07': 25.4073,
#   '2002-08': 27.0082,
#   '2002-09': 22.9985,
#   '2002-10': 22.8397,
#   '2002-11': 29.3673,
#   '2002-12': 30.6057,
#   '2003-01': 28.7982,
#   '2003-02': 30.6978,
#   '2003-03': 32.3601,
#   '2003-04': 25.1459,
#   '2003-05': 26.367,
#   '2003-06': 28.4772,
#   '2003-07': 26.5006,
#   '2003-08': 23.5854,
#   '2003-09': 18.5229,
#   '2003-10': 25.416,
#   '2003-11': 27.4365,
#   '2003-12': 24.208,
#   '2004-01': 25.4551,
#   '2004-02': 30.9381,
#   '2004-03': 28.1797,
#   '2004-04': 24.6385,
#   '2004-05': 25.2105,
#   '2004-06': 25.3845,
#   '2004-07': 21.1209,
#   '2004-08': 19.7193,
#   '2004-09': 19.0983,
#   '2004-10': 23.2234,
#   '2004-11': 26.2119,
#   '2004-12': 26.6601,
#   '2005-01': 25.9669,
#   '2005-02': 29.8857,
#   '2005-03': 31.5772,
#   '2005-04': 28.193,
#   '2005-05': 22.492,
#   '2005-06': 23.3486,
#   '2005-07': 21.4234,
#   '2005-08': 23.2849,
#   '2005-09': 22.88,
#   '2005-10': 21.5599,
#   '2005-11': 32.1714,
#   '2005-12': 29.0004,
#   '2006-01': 27.1402,
#   '2006-02': 27.8559,
#   '2006-03': 25.8542,
#   '2006-04': 23.8335,
#   '2006-05': 20.7335,
#   '2006-06': 22.9102,
#   '2006-07': 24.0984,
#   '2006-08': 20.3422,
#   '2006-09': 21.1254,
#   '2006-10': 23.9138,
#   '2006-11': 25.5945,
#   '2006-12': 26.6681,
#   '2007-01': 25.6808,
#   '2007-02': 26.3739,
#   '2007-03': 28.4958,
#   '2007-04': 22.0765,
#   '2007-05': 22.3225,
#   '2007-06': 19.6903,
#   '2007-07': 19.3137,
#   '2007-08': 20.9556,
#   '2007-09': 21.3843,
#   '2007-10': 22.2802,
#   '2007-11': 25.1952,
#   '2007-12': 25.458,
#   '2008-01': 28.4605,
#   '2008-02': 27.4393,
#   '2008-03': 24.0245,
#   '2008-04': 23.2683,
#   '2008-05': 20.6225,
#   '2008-06': 23.6482,
#   '2008-07': 21.0559,
#   '2008-08': 18.7151,
#   '2008-09': 16.3224,
#   '2008-10': 21.6775,
#   '2008-11': 22.3118,
#   '2008-12': 23.9504,
#   '2009-01': 28.339,
#   '2009-02': 27.5754,
#   '2009-03': 25.8498,
#   '2009-04': 22.9942,
#   '2009-05': 20.8881,
#   '2009-06': 17.7297,
#   '2009-07': 18.0346,
#   '2009-08': 18.0126,
#   '2009-09': 16.2197,
#   '2009-10': 19.6625,
#   '2009-11': 20.1476,
#   '2009-12': 22.2993,
#   '2010-01': 24.3089,
#   '2010-02': 23.2846,
#   '2010-03': 22.7102,
#   '2010-04': 21.1866,
#   '2010-05': 19.349,
#   '2010-06': 16.6359,
#   '2010-07': 16.0525,
#   '2010-08': 15.9032,
#   '2010-09': 15.4897,
#   '2010-10': 18.3866,
#   '2010-11': 21.1856,
#   '2010-12': 22.1514,
#   '2011-01': 28.2616,
#   '2011-02': 27.7428,
#   '2011-03': 18.1871,
#   '2011-04': 18.934,
#   '2011-05': 15.91,
#   '2011-06': 16.6109,
#   '2011-07': 16.7025,
#   '2011-08': 16.1237,
#   '2011-09': 17.7442,
#   '2011-10': 19.7863,
#   '2011-11': 26.3932,
#   '2011-12': 24.747,
#   '2012-01': 20.9465,
#   '2012-02': 22.3264,
#   '2012-03': 20.9158,
#   '2012-04': 16.6087,
#   '2012-05': 17.2421,
#   '2012-06': 14.2674,
#   '2012-07': 13.9833,
#   '2012-08': 16.7401,
#   '2012-09': 14.6688,
#   '2012-10': 16.8811,
#   '2012-11': 21.3488,
#   '2012-12': 21.2803,
#   '2013-01': 23.4841,
#   '2013-02': 21.865,
#   '2013-03': 16.9188,
#   '2013-04': 16.6716,
#   '2013-05': 17.4519,
#   '2013-06': 14.2107,
#   '2013-07': 12.7343,
#   '2013-08': 15.6082,
#   '2013-09': 15.3995,
#   '2013-10': 16.7315,
#   '2013-11': 19.3233,
#   '2013-12': 25.1914,
#   '2014-01': 25.3144,
#   '2014-02': 26.4042,
#   '2014-03': 20.6664,
#   '2014-04': 15.9945,
#   '2014-05': 13.9882,
#   '2014-06': 12.7771,
#   '2014-07': 12.9225,
#   '2014-08': 11.8977,
#   '2014-09': 14.0831,
#   '2014-10': 14.1407,
#   '2014-11': 19.9117,
#   '2014-12': 16.7151,
#   '2015-01': 21.329,
#   '2015-02': 23.8672,
#   '2015-03': 23.7944,
#   '2015-04': 16.1341,
#   '2015-05': 16.6988,
#   '2015-06': 11.5759,
#   '2015-07': 12.7429,
#   '2015-08': 12.1681,
#   '2015-09': 13.4194,
#   '2015-10': 14.839,
#   '2015-11': 19.4128,
#   '2015-12': 20.6144,
#   '2016-01': 21.62,
#   '2016-02': 18.189,
#   '2016-03': 16.6851,
#   '2016-04': 14.6608,
#   '2016-05': nan,
#   '2016-06': nan,
#   '2016-07': nan,
#   '2016-08': nan,
#   '2016-09': nan,
#   '2016-10': nan,
#   '2016-11': nan,
#   '2016-12': nan},
#  'O3': {'2000-01': 0.0118,
#   '2000-02': 0.013,
#   '2000-03': 0.0179,
#   '2000-04': 0.0233,
#   '2000-05': 0.0259,
#   '2000-06': 0.0283,
#   '2000-07': 0.0275,
#   '2000-08': 0.0223,
#   '2000-09': 0.0164,
#   '2000-10': 0.0121,
#   '2000-11': 0.0074,
#   '2000-12': 0.0084,
#   '2001-01': 0.0061,
#   '2001-02': 0.0121,
#   '2001-03': 0.0193,
#   '2001-04': 0.0249,
#   '2001-05': 0.0278,
#   '2001-06': 0.0311,
#   '2001-07': 0.0265,
#   '2001-08': 0.0303,
#   '2001-09': 0.0202,
#   '2001-10': 0.0137,
#   '2001-11': 0.0083,
#   '2001-12': 0.006,
#   '2002-01': 0.0056,
#   '2002-02': 0.0105,
#   '2002-03': 0.0149,
#   '2002-04': 0.0188,
#   '2002-05': 0.0245,
#   '2002-06': 0.0292,
#   '2002-07': 0.0335,
#   '2002-08': 0.0292,
#   '2002-09': 0.0178,
#   '2002-10': 0.0127,
#   '2002-11': 0.0067,
#   '2002-12': 0.0078,
#   '2003-01': 0.0094,
#   '2003-02': 0.0111,
#   '2003-03': 0.0158,
#   '2003-04': 0.0256,
#   '2003-05': 0.0175,
#   '2003-06': 0.0281,
#   '2003-07': 0.032,
#   '2003-08': 0.0221,
#   '2003-09': 0.0187,
#   '2003-10': 0.012,
#   '2003-11': 0.0083,
#   '2003-12': 0.0095,
#   '2004-01': 0.0097,
#   '2004-02': 0.0127,
#   '2004-03': 0.0181,
#   '2004-04': 0.0236,
#   '2004-05': 0.0235,
#   '2004-06': 0.0273,
#   '2004-07': 0.0256,
#   '2004-08': 0.0209,
#   '2004-09': 0.0174,
#   '2004-10': 0.0099,
#   '2004-11': 0.0083,
#   '2004-12': 0.0075,
#   '2005-01': 0.0085,
#   '2005-02': 0.0135,
#   '2005-03': 0.0193,
#   '2005-04': 0.0243,
#   '2005-05': 0.0246,
#   '2005-06': 0.0246,
#   '2005-07': 0.0278,
#   '2005-08': 0.0274,
#   '2005-09': 0.0229,
#   '2005-10': 0.0126,
#   '2005-11': 0.0103,
#   '2005-12': 0.0069,
#   '2006-01': 0.0076,
#   '2006-02': 0.0134,
#   '2006-03': 0.0217,
#   '2006-04': 0.0255,
#   '2006-05': 0.0271,
#   '2006-06': 0.0236,
#   '2006-07': 0.0303,
#   '2006-08': 0.0297,
#   '2006-09': 0.0198,
#   '2006-10': 0.0153,
#   '2006-11': 0.0116,
#   '2006-12': 0.0085,
#   '2007-01': 0.0099,
#   '2007-02': 0.0136,
#   '2007-03': 0.0186,
#   '2007-04': 0.0236,
#   '2007-05': 0.0275,
#   '2007-06': 0.0279,
#   '2007-07': 0.0273,
#   '2007-08': 0.0273,
#   '2007-09': 0.0215,
#   '2007-10': 0.0161,
#   '2007-11': 0.0108,
#   '2007-12': 0.0097,
#   '2008-01': 0.01,
#   '2008-02': 0.0119,
#   '2008-03': 0.0219,
#   '2008-04': 0.028,
#   '2008-05': 0.029,
#   '2008-06': 0.0323,
#   '2008-07': 0.0364,
#   '2008-08': 0.0259,
#   '2008-09': 0.0197,
#   '2008-10': 0.0127,
#   '2008-11': 0.0112,
#   '2008-12': 0.0094,
#   '2009-01': 0.0113,
#   '2009-02': 0.0169,
#   '2009-03': 0.0205,
#   '2009-04': 0.0288,
#   '2009-05': 0.0247,
#   '2009-06': 0.0213,
#   '2009-07': 0.0282,
#   '2009-08': 0.0273,
#   '2009-09': 0.0188,
#   '2009-10': 0.014,
#   '2009-11': 0.0129,
#   '2009-12': 0.0142,
#   '2010-01': 0.0139,
#   '2010-02': 0.0191,
#   '2010-03': 0.0266,
#   '2010-04': 0.0276,
#   '2010-05': 0.025,
#   '2010-06': 0.0331,
#   '2010-07': 0.0351,
#   '2010-08': 0.03,
#   '2010-09': 0.025,
#   '2010-10': 0.016,
#   '2010-11': 0.0136,
#   '2010-12': 0.0147,
#   '2011-01': 0.012,
#   '2011-02': 0.0181,
#   '2011-03': 0.0269,
#   '2011-04': 0.0258,
#   '2011-05': 0.0282,
#   '2011-06': 0.0345,
#   '2011-07': 0.0367,
#   '2011-08': 0.0276,
#   '2011-09': 0.02,
#   '2011-10': 0.0156,
#   '2011-11': 0.0124,
#   '2011-12': 0.0108,
#   '2012-01': 0.0151,
#   '2012-02': 0.019,
#   '2012-03': 0.023,
#   '2012-04': 0.0314,
#   '2012-05': 0.0272,
#   '2012-06': 0.0344,
#   '2012-07': 0.0372,
#   '2012-08': 0.0342,
#   '2012-09': 0.026,
#   '2012-10': 0.0187,
#   '2012-11': 0.0149,
#   '2012-12': 0.014,
#   '2013-01': 0.0154,
#   '2013-02': 0.0202,
#   '2013-03': 0.0287,
#   '2013-04': 0.0314,
#   '2013-05': 0.0268,
#   '2013-06': 0.0325,
#   '2013-07': 0.0324,
#   '2013-08': 0.0319,
#   '2013-09': 0.0245,
#   '2013-10': 0.0219,
#   '2013-11': 0.0179,
#   '2013-12': 0.0114,
#   '2014-01': 0.0134,
#   '2014-02': 0.0186,
#   '2014-03': 0.0248,
#   '2014-04': 0.0304,
#   '2014-05': 0.0308,
#   '2014-06': 0.0307,
#   '2014-07': 0.0339,
#   '2014-08': 0.0294,
#   '2014-09': 0.0244,
#   '2014-10': 0.0203,
#   '2014-11': 0.0159,
#   '2014-12': 0.0143,
#   '2015-01': 0.0162,
#   '2015-02': 0.0178,
#   '2015-03': 0.0216,
#   '2015-04': 0.0282,
#   '2015-05': 0.0287,
#   '2015-06': 0.0308,
#   '2015-07': 0.0344,
#   '2015-08': 0.0329,
#   '2015-09': 0.0275,
#   '2015-10': 0.0185,
#   '2015-11': 0.0164,
#   '2015-12': 0.011,
#   '2016-01': 0.0166,
#   '2016-02': 0.021,
#   '2016-03': 0.0269,
#   '2016-04': 0.0319,
#   '2016-05': nan,
#   '2016-06': nan,
#   '2016-07': nan,
#   '2016-08': nan,
#   '2016-09': nan,
#   '2016-10': nan,
#   '2016-11': nan,
#   '2016-12': nan},
#  'SO2': {'2000-01': 10.677,
#   '2000-02': 11.0958,
#   '2000-03': 5.5962,
#   '2000-04': 3.9308,
#   '2000-05': 4.4688,
#   '2000-06': 5.1381,
#   '2000-07': 4.4925,
#   '2000-08': 4.4525,
#   '2000-09': 4.7206,
#   '2000-10': 8.7093,
#   '2000-11': 11.0802,
#   '2000-12': 14.8921,
#   '2001-01': 21.0247,
#   '2001-02': 11.7652,
#   '2001-03': 9.0253,
#   '2001-04': 7.2904,
#   '2001-05': 5.0954,
#   '2001-06': 4.1711,
#   '2001-07': 3.9304,
#   '2001-08': 5.3357,
#   '2001-09': 3.9766,
#   '2001-10': 8.0894,
#   '2001-11': 9.8938,
#   '2001-12': 11.5889,
#   '2002-01': 14.8736,
#   '2002-02': 10.8606,
#   '2002-03': 9.6076,
#   '2002-04': 5.3172,
#   '2002-05': 4.0635,
#   '2002-06': 4.4,
#   '2002-07': 4.0696,
#   '2002-08': 4.2974,
#   '2002-09': 3.5394,
#   '2002-10': 4.9052,
#   '2002-11': 10.9066,
#   '2002-12': 14.25,
#   '2003-01': 15.1982,
#   '2003-02': 14.4089,
#   '2003-03': 10.1729,
#   '2003-04': 5.2976,
#   '2003-05': 3.7476,
#   '2003-06': 3.9947,
#   '2003-07': 4.6722,
#   '2003-08': 3.6915,
#   '2003-09': 2.8486,
#   '2003-10': 7.2999,
#   '2003-11': 10.3732,
#   '2003-12': 11.999,
#   '2004-01': 13.018,
#   '2004-02': 12.7125,
#   '2004-03': 8.3484,
#   '2004-04': 5.1565,
#   '2004-05': 3.4787,
#   '2004-06': 3.7824,
#   '2004-07': 3.9331,
#   '2004-08': 4.2879,
#   '2004-09': 3.3225,
#   '2004-10': 5.2917,
#   '2004-11': 11.0274,
#   '2004-12': 12.4898,
#   '2005-01': 10.1522,
#   '2005-02': 12.0237,
#   '2005-03': 9.964,
#   '2005-04': 6.3678,
#   '2005-05': 4.2436,
#   '2005-06': 4.7533,
#   '2005-07': 3.8591,
#   '2005-08': 4.6554,
#   '2005-09': 4.5122,
#   '2005-10': 5.3903,
#   '2005-11': 10.7528,
#   '2005-12': 15.3576,
#   '2006-01': 10.5681,
#   '2006-02': 10.8411,
#   '2006-03': 6.2923,
#   '2006-04': 4.0903,
#   '2006-05': 2.6677,
#   '2006-06': 3.1133,
#   '2006-07': 4.5011,
#   '2006-08': 2.766,
#   '2006-09': 2.4641,
#   '2006-10': 5.185,
#   '2006-11': 6.9926,
#   '2006-12': 11.0698,
#   '2007-01': 10.8615,
#   '2007-02': 12.9036,
#   '2007-03': 7.5032,
#   '2007-04': 4.6816,
#   '2007-05': 3.2988,
#   '2007-06': 2.8481,
#   '2007-07': 3.2766,
#   '2007-08': 2.7535,
#   '2007-09': 2.3858,
#   '2007-10': 3.5345,
#   '2007-11': 6.2422,
#   '2007-12': 7.5968,
#   '2008-01': 9.9101,
#   '2008-02': 8.6103,
#   '2008-03': 5.1175,
#   '2008-04': 3.3445,
#   '2008-05': 2.647,
#   '2008-06': 3.2217,
#   '2008-07': 3.2385,
#   '2008-08': 2.0428,
#   '2008-09': 1.7009,
#   '2008-10': 4.5549,
#   '2008-11': 5.9809,
#   '2008-12': 7.541,
#   '2009-01': 11.0732,
#   '2009-02': 8.4235,
#   '2009-03': 5.9604,
#   '2009-04': 3.8664,
#   '2009-05': 1.9482,
#   '2009-06': 1.3112,
#   '2009-07': 1.7632,
#   '2009-08': 2.0725,
#   '2009-09': 1.6398,
#   '2009-10': 3.2415,
#   '2009-11': 3.8726,
#   '2009-12': 7.0564,
#   '2010-01': 8.5344,
#   '2010-02': 7.0018,
#   '2010-03': 4.5017,
#   '2010-04': 2.7755,
#   '2010-05': 1.6819,
#   '2010-06': 1.7322,
#   '2010-07': 1.6571,
#   '2010-08': 1.5272,
#   '2010-09': 1.6094,
#   '2010-10': 2.5471,
#   '2010-11': 4.8045,
#   '2010-12': 7.7593,
#   '2011-01': 9.7475,
#   '2011-02': 7.9692,
#   '2011-03': 3.7319,
#   '2011-04': 2.6568,
#   '2011-05': 1.4633,
#   '2011-06': 1.6952,
#   '2011-07': 1.8661,
#   '2011-08': 1.7312,
#   '2011-09': 1.837,
#   '2011-10': 2.5833,
#   '2011-11': 4.565,
#   '2011-12': 5.5785,
#   '2012-01': 5.2757,
#   '2012-02': 5.0741,
#   '2012-03': 2.9064,
#   '2012-04': 2.2242,
#   '2012-05': 1.2396,
#   '2012-06': 1.3416,
#   '2012-07': 1.3701,
#   '2012-08': 1.2773,
#   '2012-09': 1.1395,
#   '2012-10': 1.5034,
#   '2012-11': 3.4442,
#   '2012-12': 3.4905,
#   '2013-01': 4.5608,
#   '2013-02': 3.44,
#   '2013-03': 2.2489,
#   '2013-04': 1.2144,
#   '2013-05': 0.9041,
#   '2013-06': 0.8645,
#   '2013-07': 0.8027,
#   '2013-08': 0.8269,
#   '2013-09': 0.7749,
#   '2013-10': 1.2341,
#   '2013-11': 1.9815,
#   '2013-12': 2.9344,
#   '2014-01': 3.8295,
#   '2014-02': 3.5077,
#   '2014-03': 2.1546,
#   '2014-04': 0.984,
#   '2014-05': 0.7639,
#   '2014-06': 0.5527,
#   '2014-07': 0.6204,
#   '2014-08': 0.5892,
#   '2014-09': 0.6619,
#   '2014-10': 0.7896,
#   '2014-11': 1.7822,
#   '2014-12': 1.4322,
#   '2015-01': 2.4013,
#   '2015-02': 2.8636,
#   '2015-03': 1.612,
#   '2015-04': 0.6266,
#   '2015-05': 0.488,
#   '2015-06': 0.3084,
#   '2015-07': 0.4311,
#   '2015-08': 0.487,
#   '2015-09': 0.4355,
#   '2015-10': 0.6504,
#   '2015-11': 0.8939,
#   '2015-12': 0.9741,
#   '2016-01': 1.5996,
#   '2016-02': 1.0912,
#   '2016-03': 0.8835,
#   '2016-04': 0.5973,
#   '2016-05': nan,
#   '2016-06': nan,
#   '2016-07': nan,
#   '2016-08': nan,
#   '2016-09': nan,
#   '2016-10': nan,
#   '2016-11': nan,
#   '2016-12': nan},
#  'CO': {'2000-01': 0.4773,
#   '2000-02': 0.7063,
#   '2000-03': 0.5298,
#   '2000-04': 0.4443,
#   '2000-05': 0.5264,
#   '2000-06': 0.6239,
#   '2000-07': 0.599,
#   '2000-08': 0.6413,
#   '2000-09': 0.5924,
#   '2000-10': 0.7532,
#   '2000-11': 0.676,
#   '2000-12': 0.7018,
#   '2001-01': 0.8532,
#   '2001-02': 0.5759,
#   '2001-03': 0.5487,
#   '2001-04': 0.5751,
#   '2001-05': 0.5525,
#   '2001-06': 0.5312,
#   '2001-07': 0.3819,
#   '2001-08': 0.5414,
#   '2001-09': 0.6349,
#   '2001-10': 0.6461,
#   '2001-11': 0.712,
#   '2001-12': 0.7411,
#   '2002-01': 0.7064,
#   '2002-02': 0.6296,
#   '2002-03': 0.6088,
#   '2002-04': 0.4855,
#   '2002-05': 0.542,
#   '2002-06': 0.5491,
#   '2002-07': 0.6015,
#   '2002-08': 0.6342,
#   '2002-09': 0.6527,
#   '2002-10': 0.5514,
#   '2002-11': 0.6883,
#   '2002-12': 0.7246,
#   '2003-01': 0.698,
#   '2003-02': 0.7068,
#   '2003-03': 0.7482,
#   '2003-04': 0.5641,
#   '2003-05': 0.7217,
#   '2003-06': 0.7524,
#   '2003-07': 0.6553,
#   '2003-08': 0.6734,
#   '2003-09': 0.6787,
#   '2003-10': 0.7293,
#   '2003-11': 0.8486,
#   '2003-12': 0.5741,
#   '2004-01': 0.5217,
#   '2004-02': 0.6106,
#   '2004-03': 0.5665,
#   '2004-04': 0.5903,
#   '2004-05': 0.6321,
#   '2004-06': 0.5698,
#   '2004-07': 0.5754,
#   '2004-08': 0.6086,
#   '2004-09': 0.593,
#   '2004-10': 0.4784,
#   '2004-11': 0.5612,
#   '2004-12': 0.6378,
#   '2005-01': 0.6501,
#   '2005-02': 0.5947,
#   '2005-03': 0.5416,
#   '2005-04': 0.4706,
#   '2005-05': 0.5151,
#   '2005-06': 0.536,
#   '2005-07': 0.5467,
#   '2005-08': 0.5323,
#   '2005-09': 0.662,
#   '2005-10': 0.5458,
#   '2005-11': 0.5601,
#   '2005-12': 0.542,
#   '2006-01': 0.5301,
#   '2006-02': 0.4675,
#   '2006-03': 0.4115,
#   '2006-04': 0.528,
#   '2006-05': 0.3714,
#   '2006-06': 0.3596,
#   '2006-07': 0.4357,
#   '2006-08': 0.5205,
#   '2006-09': 0.5318,
#   '2006-10': 0.5216,
#   '2006-11': 0.5695,
#   '2006-12': 0.4827,
#   '2007-01': 0.5641,
#   '2007-02': 0.526,
#   '2007-03': 0.5144,
#   '2007-04': 0.4895,
#   '2007-05': 0.4032,
#   '2007-06': 0.4103,
#   '2007-07': 0.4192,
#   '2007-08': 0.5827,
#   '2007-09': 0.5069,
#   '2007-10': 0.5471,
#   '2007-11': 0.5874,
#   '2007-12': 0.536,
#   '2008-01': 0.567,
#   '2008-02': 0.5529,
#   '2008-03': 0.3895,
#   '2008-04': 0.4201,
#   '2008-05': 0.4358,
#   '2008-06': 0.4227,
#   '2008-07': 0.4854,
#   '2008-08': 0.6149,
#   '2008-09': 0.4886,
#   '2008-10': 0.5146,
#   '2008-11': 0.5036,
#   '2008-12': 0.5153,
#   '2009-01': 0.5152,
#   '2009-02': 0.6355,
#   '2009-03': 0.4477,
#   '2009-04': 0.473,
#   '2009-05': 0.4768,
#   '2009-06': 0.199,
#   '2009-07': 0.4074,
#   '2009-08': 0.3932,
#   '2009-09': 0.3364,
#   '2009-10': 0.2972,
#   '2009-11': 0.3446,
#   '2009-12': 0.2789,
#   '2010-01': 0.5714,
#   '2010-02': 0.4611,
#   '2010-03': 0.4044,
#   '2010-04': 0.4287,
#   '2010-05': 0.4481,
#   '2010-06': 0.4257,
#   '2010-07': 0.4447,
#   '2010-08': 0.383,
#   '2010-09': 0.4401,
#   '2010-10': 0.4451,
#   '2010-11': 0.5086,
#   '2010-12': 0.4266,
#   '2011-01': 0.4574,
#   '2011-02': 0.4163,
#   '2011-03': 0.3001,
#   '2011-04': 0.33,
#   '2011-05': 0.3067,
#   '2011-06': 0.3747,
#   '2011-07': 0.4048,
#   '2011-08': 0.3821,
#   '2011-09': 0.4687,
#   '2011-10': 0.3138,
#   '2011-11': 0.5117,
#   '2011-12': 0.4156,
#   '2012-01': 0.3344,
#   '2012-02': 0.3625,
#   '2012-03': 0.3452,
#   '2012-04': 0.264,
#   '2012-05': 0.3179,
#   '2012-06': 0.3188,
#   '2012-07': 0.3318,
#   '2012-08': 0.3808,
#   '2012-09': 0.301,
#   '2012-10': 0.3776,
#   '2012-11': 0.3268,
#   '2012-12': 0.4555,
#   '2013-01': 0.4031,
#   '2013-02': 0.3669,
#   '2013-03': 0.3012,
#   '2013-04': 0.2682,
#   '2013-05': 0.3127,
#   '2013-06': 0.2842,
#   '2013-07': 0.3132,
#   '2013-08': 0.349,
#   '2013-09': 0.2185,
#   '2013-10': 0.2466,
#   '2013-11': 0.2456,
#   '2013-12': 0.3586,
#   '2014-01': 0.3233,
#   '2014-02': 0.3878,
#   '2014-03': 0.3385,
#   '2014-04': 0.2526,
#   '2014-05': 0.2505,
#   '2014-06': 0.2034,
#   '2014-07': 0.2028,
#   '2014-08': 0.2211,
#   '2014-09': 0.2257,
#   '2014-10': 0.2477,
#   '2014-11': 0.3408,
#   '2014-12': 0.3181,
#   '2015-01': 0.337,
#   '2015-02': 0.3348,
#   '2015-03': 0.3731,
#   '2015-04': 0.2337,
#   '2015-05': 0.2205,
#   '2015-06': 0.1967,
#   '2015-07': 0.2395,
#   '2015-08': 0.18,
#   '2015-09': 0.1945,
#   '2015-10': 0.1855,
#   '2015-11': 0.303,
#   '2015-12': 0.3515,
#   '2016-01': 0.3243,
#   '2016-02': 0.2914,
#   '2016-03': 0.2966,
#   '2016-04': 0.2593,
#   '2016-05': nan,
#   '2016-06': nan,
#   '2016-07': nan,
#   '2016-08': nan,
#   '2016-09': nan,
#   '2016-10': nan,
#   '2016-11': nan,
#   '2016-12': nan}}

# %%
ny_gases_df = pd.DataFrame(ny_avg_gases).dropna()
ny_gases_df = ny_gases_df.reset_index()
ny_gases_df = ny_gases_df.rename({'index': 'Years_Months'}, axis='columns')

# %%
ny_gases_df
# Out:
#     Years_Months      NO2      O3      SO2      CO
# 0        2000-01  26.1259  0.0118  10.6770  0.4773
# 1        2000-02  31.1326  0.0130  11.0958  0.7063
# 2        2000-03  27.9750  0.0179   5.5962  0.5298
# 3        2000-04  22.4492  0.0233   3.9308  0.4443
# 4        2000-05  26.8353  0.0259   4.4688  0.5264
# ..           ...      ...     ...      ...     ...
# 191      2015-12  20.6144  0.0110   0.9741  0.3515
# 192      2016-01  21.6200  0.0166   1.5996  0.3243
# 193      2016-02  18.1890  0.0210   1.0912  0.2914
# 194      2016-03  16.6851  0.0269   0.8835  0.2966
# 195      2016-04  14.6608  0.0319   0.5973  0.2593
#
# [196 rows x 5 columns]

# %%
ny_gases_df['Year'] = ny_gases_df['Years_Months'].str.split('-', expand=True)[0]
ny_gases_df['Month'] = ny_gases_df['Years_Months'].str.split('-', expand=True)[1]
ny_gases_df
# Out:
#     Years_Months      NO2      O3      SO2      CO  Year Month
# 0        2000-01  26.1259  0.0118  10.6770  0.4773  2000    01
# 1        2000-02  31.1326  0.0130  11.0958  0.7063  2000    02
# 2        2000-03  27.9750  0.0179   5.5962  0.5298  2000    03
# 3        2000-04  22.4492  0.0233   3.9308  0.4443  2000    04
# 4        2000-05  26.8353  0.0259   4.4688  0.5264  2000    05
# ..           ...      ...     ...      ...     ...   ...   ...
# 191      2015-12  20.6144  0.0110   0.9741  0.3515  2015    12
# 192      2016-01  21.6200  0.0166   1.5996  0.3243  2016    01
# 193      2016-02  18.1890  0.0210   1.0912  0.2914  2016    02
# 194      2016-03  16.6851  0.0269   0.8835  0.2966  2016    03
# 195      2016-04  14.6608  0.0319   0.5973  0.2593  2016    04
#
# [196 rows x 7 columns]

# %%
ny_gases_df.plot.line(figsize=(17,10), y='NO2', x='Years_Months')

# %%
climate_data = pd.read_csv('data/climate_data.csv')
climate_data
# Out:
#           State     City  Month  Day  Year  Average_Temperature      Date
# 0       Arizona  Phoenix      1    1  2000                 56.4  1/1/2000
# 1       Arizona  Phoenix      1    2  2000                 49.1  1/2/2000
# 2       Arizona  Phoenix      1    3  2000                 45.8  1/3/2000
# 3       Arizona  Phoenix      1    4  2000                 51.5  1/4/2000
# 4       Arizona  Phoenix      1    5  2000                 47.9  1/5/2000
# ...         ...      ...    ...  ...   ...                  ...       ...
# 103798    Texas   Dallas      5    9  2020                 62.3    5/9/20
# 103799    Texas   Dallas      5   10  2020                 65.3   5/10/20
# 103800    Texas   Dallas      5   11  2020                 68.9   5/11/20
# 103801    Texas   Dallas      5   12  2020                 71.8   5/12/20
# 103802    Texas   Dallas      5   13  2020                 69.1   5/13/20
#
# [103803 rows x 7 columns]

# %%
climate_mask = (climate_data['Year'] < 2016)
climate_data = climate_data[climate_mask]
climate_data
# Out:
#           State     City  Month  Day  Year  Average_Temperature      Date
# 0       Arizona  Phoenix      1    1  2000                 56.4  1/1/2000
# 1       Arizona  Phoenix      1    2  2000                 49.1  1/2/2000
# 2       Arizona  Phoenix      1    3  2000                 45.8  1/3/2000
# 3       Arizona  Phoenix      1    4  2000                 51.5  1/4/2000
# 4       Arizona  Phoenix      1    5  2000                 47.9  1/5/2000
# ...         ...      ...    ...  ...   ...                  ...       ...
# 102227    Texas   Dallas     12   26  2015                 72.6  12/26/15
# 102228    Texas   Dallas     12   27  2015                 48.9  12/27/15
# 102229    Texas   Dallas     12   28  2015                 38.8  12/28/15
# 102230    Texas   Dallas     12   29  2015                 37.6  12/29/15
# 102231    Texas   Dallas     12   30  2015                 42.2  12/30/15
#
# [81545 rows x 7 columns]

# %% [markdown]
# <h1>Checking NO2 data</h1>

# %%
no2_max = data['NO2 Mean'].max()
no2_max

# %%
no2_min = data['NO2 Mean'].min()
no2_min

# %%
no2_max = data.loc[data['NO2 Mean'] == data['NO2 Mean'].max(), 'City']
no2_max.get(no2_max.index[0])

# %%
no2_min = data.loc[data['NO2 Mean'] == data['NO2 Mean'].min(), 'City']
no2_min.get(no2_min.index[0])

# %%
data_in_order_no2 = data[['NO2 Mean', 'City']].sort_values(by='NO2 Mean', ascending=False)
data_in_order_no2.head(1)

# %%
data_in_order_no2.tail(1)

# %%
data.plot(kind='scatter', x='NO2 Mean', y='City', figsize=(10,6))

# %% [markdown]
# <h1>Checking O3 data</h1>

# %%
o3_max = data['O3 Mean'].max()
o3_max

# %%
o3_min = data['O3 Mean'].min()
o3_min

# %%
o3_max = data.loc[data['O3 Mean'] == data['O3 Mean'].max(), 'City']
o3_max.get(o3_max.index[0])

# %%
o3_min = data.loc[data['O3 Mean'] == data['O3 Mean'].min(), 'City']
o3_min.get(o3_min.index[0])

# %%
data_in_order_o3 = data[['O3 Mean', 'City']].sort_values(by='O3 Mean', ascending=False)
data_in_order_o3.head(1)

# %%
data_in_order_o3 = data[['O3 Mean', 'City']].sort_values(by='O3 Mean', ascending=False)
data_in_order_o3.tail(1)

# %%
data.plot(kind='scatter', x='O3 Mean', y='City', figsize=(10,6))

# %% [markdown]
# <h1>Checking SO2 data</h1>

# %%
so2_max = data['SO2 Mean'].max()
so2_max

# %%
so2_min = data['SO2 Mean'].min()
so2_min

# %%
so2_max = data.loc[data['SO2 Mean'] == data['SO2 Mean'].max(), 'City']
so2_max.get(so2_max.index[0])

# %%
so2_min = data.loc[data['SO2 Mean'] == data['SO2 Mean'].min(), 'City']
so2_min.get(so2_min.index[0])

# %%
data_in_order_so2 = data[['SO2 Mean', 'City']].sort_values(by='SO2 Mean', ascending=False)
data_in_order_so2.head(1)

# %%
data_in_order_so2 = data[['SO2 Mean', 'City']].sort_values(by='SO2 Mean', ascending=False)
data_in_order_so2.tail(1)

# %%
data.plot(kind='scatter', x='SO2 Mean', y='City', figsize=(10,6))

# %% [markdown]
# <h1>Checking CO data</h1>

# %%
co_max = data['CO Mean'].max()
co_max

# %%
co_min = data['CO Mean'].min()
co_min

# %%
co_max = data.loc[data['CO Mean'] == data['CO Mean'].max(), 'City']
co_max.get(co_max.index[0])

# %%
co_min = data.loc[data['CO Mean'] == data['CO Mean'].min(), 'City']
co_min.get(co_min.index[0])

# %%
data_in_order_co = data[['CO Mean', 'City']].sort_values(by='CO Mean', ascending=False)
data_in_order_co.head(1)

# %%
data_in_order_co = data[['CO Mean', 'City']].sort_values(by='CO Mean', ascending=False)
data_in_order_co.tail(1)

# %%
data.plot(kind='scatter', x='CO Mean', y='City', figsize=(10,6))
